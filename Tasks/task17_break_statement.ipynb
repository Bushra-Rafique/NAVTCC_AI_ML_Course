# %% [markdown]
# # Task 17 – Break Statement in Python
# **Reference:** https://www.geeksforgeeks.org/python-break-statement/

# %% [markdown]
# ## Break in for loop

# %%
for i in range(10):
    if i == 5:
        print('Breaking at', i)
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# Breaking at 5

# %% [markdown]
# ## Break in while loop

# %%
num = 0
while num < 10:
    if num == 4:
        break
    print(num)
    num += 1
# Out:
# 0
# 1
# 2
# 3
